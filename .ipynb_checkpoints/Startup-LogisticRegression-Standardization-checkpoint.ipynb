# %%
import pandas as pd
df = pd.read_csv('ks-projects-201801.csv')

# %%
df.shape
# Out:
# (378661, 15)

# %% [markdown]
# ### Data Cleansing
#
# Removing nulls, checking types, checking row uniqueness, checking data values, getting timeframe differrence, checking if some data is invalid(I dont' see a rule in this last point)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (374860, 15)

# %%
df.dtypes
# Out:
# ID                    int64
# name                 object
# category             object
# main_category        object
# currency             object
# deadline             object
# goal                float64
# launched             object
# pledged             float64
# state                object
# backers               int64
# country              object
# usd pledged         float64
# usd_pledged_real    float64
# usd_goal_real       float64
# dtype: object

# %% [markdown]
# ###### the numbered data are really numbers, no need to convert any type

# %%
df['state'].value_counts()
# Out:
# failed        197611
# successful    133851
# canceled       38757
# live            2798
# suspended       1843
# Name: state, dtype: int64

# %% [markdown]
# ###### Above seems we will need to keep only the "failed" and "succesfful" states. But first let us get rid of some of unseful columns

# %%
df.drop(['ID','category','currency'],axis=1,inplace=True)

# %% [markdown]
# ###### generating the timeframe columns then get rid of the deadline and launched columns

# %%
from datetime import datetime
def days_between(dd1, dd2):
    ddres=[]
    for d1,d2 in zip(dd1,dd2):
        d1 = datetime.strptime(d1, "%Y-%m-%d")
        d2 = datetime.strptime(d2, "%Y-%m-%d %H:%M:%S")
        ddres.append(abs((d2 - d1).days))
    return ddres

df['timeframe']=days_between(df['deadline'],df['launched'])

# %%
df.drop(['deadline','launched'],axis=1, inplace=True)
df.head()
# Out:
#                                                 name main_category     goal  \
# 0                    The Songs of Adelaide & Abullah    Publishing   1000.0
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Film & Video  30000.0
# 2                                     Where is Hank?  Film & Video  45000.0
# 3  ToshiCapital Rekordz Needs Help to Complete Album         Music   5000.0
# 4  Community Film Project: The Art of Neighborhoo...  Film & Video  19500.0
#
#    pledged     state  backers country  usd pledged  usd_pledged_real  \
# 0      0.0    failed        0      GB          0.0               0.0
# 1   2421.0    failed       15      US        100.0            2421.0
# 2    220.0    failed        3      US        220.0             220.0
# 3      1.0    failed        1      US          1.0               1.0
# 4   1283.0  canceled       14      US       1283.0            1283.0
#
#    usd_goal_real  timeframe
# 0        1533.95         59
# 1       30000.00         60
# 2       45000.00         45
# 3        5000.00         30
# 4       19500.00         56

# %%
df=df[df.state.isin(['failed','successful'])]

# %%
df.shape
# Out:
# (331462, 11)

# %%
df
# Out:
#                                                      name main_category  \
# 0                         The Songs of Adelaide & Abullah    Publishing
# 1           Greeting From Earth: ZGAC Arts Capsule For ET  Film & Video
# 2                                          Where is Hank?  Film & Video
# 3       ToshiCapital Rekordz Needs Help to Complete Album         Music
# 5                                    Monarch Espresso Bar          Food
# ...                                                   ...           ...
# 378654              Homemade fresh dog food, Cleveland OH          Food
# 378657                                          The Tribe  Film & Video
# 378658  Walls of Remedy- New lesbian Romantic Comedy f...  Film & Video
# 378659                           BioDefense Education Kit    Technology
# 378660                  Nou Renmen Ayiti!  We Love Haiti!           Art
#
#            goal  pledged       state  backers country  usd pledged  \
# 0        1000.0      0.0      failed        0      GB          0.0
# 1       30000.0   2421.0      failed       15      US        100.0
# 2       45000.0    220.0      failed        3      US        220.0
# 3        5000.0      1.0      failed        1      US          1.0
# 5       50000.0  52375.0  successful      224      US      52375.0
# ...         ...      ...         ...      ...     ...          ...
# 378654   6500.0    154.0      failed        4      US          0.0
# 378657   1500.0    155.0      failed        5      US        155.0
# 378658  15000.0     20.0      failed        1      US         20.0
# 378659  15000.0    200.0      failed        6      US        200.0
# 378660   2000.0    524.0      failed       17      US        524.0
#
#         usd_pledged_real  usd_goal_real  timeframe
# 0                    0.0        1533.95         59
# 1                 2421.0       30000.00         60
# 2                  220.0       45000.00         45
# 3                    1.0        5000.00         30
# 5                52375.0       50000.00         35
# ...                  ...            ...        ...
# 378654             154.0        6500.00         30
# 378657             155.0        1500.00         27
# 378658              20.0       15000.00         46
# 378659             200.0       15000.00         31
# 378660             524.0        2000.00         28
#
# [331462 rows x 11 columns]

# %% [markdown]
# chaning state column to 0 or 1

# %%
df.loc[df['state']=='failed','result']=0
df.loc[df['state']=='successful','result']=1

# %%
df.drop(['country','name','state'],axis=1,inplace=True)
df.drop_duplicates(inplace=True)

# %%
import matplotlib.pyplot as plt
#fig, ax = plt.subplots(num=None, figsize=(10, 4), dpi=80, facecolor='w', edgecolor='k')
#ax.boxplot(df['backers'])
#ax.hist(df['goal'].T)
#plt.show()
df[['backers','goal','timeframe']].hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022AEBE88F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022AF3A30EC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022AE04B21C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022AE3748E08>]],
#       dtype=object)

# %% [markdown]
# Above shows that timeframe has a normal distribution, while others are very centric

# %%
features=df.drop('result',axis=1)
labels=df['result']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.33, random_state=42)

# %% [markdown]
# # Centring data

# %%
# hot encoding and keepying the lb_style for prediction
from sklearn.preprocessing import LabelBinarizer
lb_style = LabelBinarizer()
lb_style.fit(X_train["main_category"],)
x_train=lb_style.transform(X_train['main_category'])
x_test=lb_style.transform(X_test['main_category'])
#dfd=df.join(pd.DataFrame(lb_results, columns=lb_style.classes_, index = df.index))
#df = dfd.drop('main_category',axis=1)

# %%
X_train=X_train.drop('main_category',axis=1).join(pd.DataFrame(x_train,columns=lb_style.classes_,index=X_train.index))
X_test=X_test.drop('main_category',axis=1).join(pd.DataFrame(x_test,columns=lb_style.classes_,index=X_test.index))
X_train
X_test
# Out:
#             goal    pledged  backers  usd pledged  usd_pledged_real  \
# 124323     500.0      50.00        2        50.00             50.00
# 330593    6000.0      65.00        4        65.00             65.00
# 52006      500.0      10.00        2        10.00             10.00
# 238413    2000.0    2055.77       49      2055.77           2055.77
# 308207    5000.0    7016.00       54      7016.00           7016.00
# ...          ...        ...      ...          ...               ...
# 288107  100000.0  145650.00       58     17334.25          18665.66
# 215153     500.0     250.00        1       250.00            250.00
# 314475   13000.0   16034.00      315     16034.00          16034.00
# 318464     750.0     782.00       24         0.00            597.91
# 129826   25000.0     410.00        6       338.94            315.92
#
#         usd_goal_real  timeframe  Art  Comics  Crafts  ...  Fashion  \
# 124323         500.00         14    0       0       0  ...        0
# 330593        6000.00         60    0       1       0  ...        0
# 52006          500.00         15    0       0       0  ...        0
# 238413        2000.00         47    0       0       0  ...        0
# 308207        5000.00         30    0       0       0  ...        0
# ...               ...        ...  ...     ...     ...  ...      ...
# 288107       12815.42         30    0       0       0  ...        0
# 215153         500.00         60    0       0       0  ...        0
# 314475       13000.00         33    0       0       0  ...        0
# 318464         573.44         36    1       0       0  ...        0
# 129826       19263.37         60    0       0       0  ...        0
#
#         Film & Video  Food  Games  Journalism  Music  Photography  Publishing  \
# 124323             0     0      0           0      0            1           0
# 330593             0     0      0           0      0            0           0
# 52006              0     0      0           0      0            1           0
# 238413             0     0      0           0      1            0           0
# 308207             1     0      0           0      0            0           0
# ...              ...   ...    ...         ...    ...          ...         ...
# 288107             0     0      0           0      0            0           0
# 215153             1     0      0           0      0            0           0
# 314475             0     0      0           0      1            0           0
# 318464             0     0      0           0      0            0           0
# 129826             0     0      0           0      0            0           1
#
#         Technology  Theater
# 124323           0        0
# 330593           0        0
# 52006            0        0
# 238413           0        0
# 308207           0        0
# ...            ...      ...
# 288107           0        0
# 215153           0        0
# 314475           0        0
# 318464           0        0
# 129826           0        0
#
# [100765 rows x 22 columns]

# %% [markdown]
# ### Standardization of all

# %%
from sklearn import preprocessing
# Get column names first
names = X_train.columns
# Create the Scaler object
scaler = preprocessing.StandardScaler()
# Fit your data on the scaler object
scaler.fit(X_train)
train=scaler.transform(X_train)
test=scaler.transform(X_test)
X_train= pd.DataFrame(train, columns=names)
X_test= pd.DataFrame(test, columns=names)
X_test.head()
# Out:
#        goal   pledged   backers  usd pledged  usd_pledged_real  usd_goal_real  \
# 0 -0.038880 -0.106224 -0.122004    -0.094703         -0.105176      -0.036749
# 1 -0.034330 -0.106086 -0.120068    -0.094535         -0.105031      -0.032166
# 2 -0.038880 -0.106592 -0.122004    -0.095153         -0.105562      -0.036749
# 3 -0.037639 -0.087802 -0.076515    -0.072156         -0.085801      -0.035500
# 4 -0.035157 -0.042245 -0.071676    -0.016399         -0.037886      -0.033000
#
#    timeframe       Art    Comics    Crafts  ...   Fashion  Film & Video  \
# 0  -1.551903 -0.290628 -0.181422 -0.154076  ... -0.246782     -0.450383
# 1   2.037374 -0.290628  5.512011 -0.154076  ... -0.246782     -0.450383
# 2  -1.473875 -0.290628 -0.181422 -0.154076  ... -0.246782     -0.450383
# 3   1.023013 -0.290628 -0.181422 -0.154076  ... -0.246782     -0.450383
# 4  -0.303459 -0.290628 -0.181422 -0.154076  ... -0.246782      2.220334
#
#        Food     Games  Journalism     Music  Photography  Publishing  \
# 0 -0.263136 -0.316468   -0.111451 -0.396160     5.726004     -0.3366
# 1 -0.263136 -0.316468   -0.111451 -0.396160    -0.174642     -0.3366
# 2 -0.263136 -0.316468   -0.111451 -0.396160     5.726004     -0.3366
# 3 -0.263136 -0.316468   -0.111451  2.524234    -0.174642     -0.3366
# 4 -0.263136 -0.316468   -0.111451 -0.396160    -0.174642     -0.3366
#
#    Technology   Theater
# 0   -0.295945 -0.183823
# 1   -0.295945 -0.183823
# 2   -0.295945 -0.183823
# 3   -0.295945 -0.183823
# 4   -0.295945 -0.183823
#
# [5 rows x 22 columns]

# %%
X_test.shape[0]+X_train.shape[0]
# Out:
# 305346

# %% [markdown]
.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# ..

# %%
X_train.median()
# Out:
# goal               -0.035157
# pledged            -0.096856
# backers            -0.105551
# usd pledged        -0.087397
# usd_pledged_real   -0.095252
# usd_goal_real      -0.033000
# timeframe          -0.303459
# Art                -0.290628
# Comics             -0.181422
# Crafts             -0.154076
# Dance              -0.107053
# Design             -0.297661
# Fashion            -0.246782
# Film & Video       -0.450383
# Food               -0.263136
# Games              -0.316468
# Journalism         -0.111451
# Music              -0.396160
# Photography        -0.174642
# Publishing         -0.336600
# Technology         -0.295945
# Theater            -0.183823
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
#ax.boxplot(df['backers'])
ax.hist(X_train['timeframe'])
# Out:
# (array([  4128.,  10971.,  22542., 116893.,  22759.,   5410.,  19451.,
#            464.,    319.,   1644.]),
#  array([-2.5662636 , -1.85621109, -1.14615857, -0.43610605,  0.27394647,
#          0.98399899,  1.6940515 ,  2.40410402,  3.11415654,  3.82420906,
#          4.53426158]),
#  <a list of 10 Patch objects>)

# %%
str(X_train.shape) + str(X_test.shape)
# Out:
# '(204581, 22)(100765, 22)'

# %%
#from sklearn.decomposition import PCA
#pca = PCA(n_components=len(X_train.columns)-2)
#pca.fit(X_train)
#train=pca.transform(X_train)
#test=pca.transform(X_test)
#X_train= pd.DataFrame(data = train)
#X_test = pd.DataFrame(data = test)

# %%
X_test
# Out:
#             goal   pledged   backers  usd pledged  usd_pledged_real  \
# 0      -0.038880 -0.106224 -0.122004    -0.094703         -0.105176
# 1      -0.034330 -0.106086 -0.120068    -0.094535         -0.105031
# 2      -0.038880 -0.106592 -0.122004    -0.095153         -0.105562
# 3      -0.037639 -0.087802 -0.076515    -0.072156         -0.085801
# 4      -0.035157 -0.042245 -0.071676    -0.016399         -0.037886
# ...          ...       ...       ...          ...               ...
# 100760  0.043433  1.231035 -0.067804     0.099588          0.074646
# 100761 -0.038880 -0.104387 -0.122972    -0.092455         -0.103244
# 100762 -0.028539  0.040580  0.180934     0.084972          0.049225
# 100763 -0.038673 -0.099501 -0.100711    -0.095265         -0.099883
# 100764 -0.018612 -0.102918 -0.118133    -0.091455         -0.102607
#
#         usd_goal_real  timeframe       Art    Comics    Crafts  ...   Fashion  \
# 0           -0.036749  -1.551903 -0.290628 -0.181422 -0.154076  ... -0.246782
# 1           -0.032166   2.037374 -0.290628  5.512011 -0.154076  ... -0.246782
# 2           -0.036749  -1.473875 -0.290628 -0.181422 -0.154076  ... -0.246782
# 3           -0.035500   1.023013 -0.290628 -0.181422 -0.154076  ... -0.246782
# 4           -0.033000  -0.303459 -0.290628 -0.181422 -0.154076  ... -0.246782
# ...               ...        ...       ...       ...       ...  ...       ...
# 100760      -0.026487  -0.303459 -0.290628 -0.181422 -0.154076  ... -0.246782
# 100761      -0.036749   2.037374 -0.290628 -0.181422 -0.154076  ... -0.246782
# 100762      -0.026334  -0.069376 -0.290628 -0.181422 -0.154076  ... -0.246782
# 100763      -0.036688   0.164708  3.440825 -0.181422 -0.154076  ... -0.246782
# 100764      -0.021115   2.037374 -0.290628 -0.181422 -0.154076  ... -0.246782
#
#         Film & Video      Food     Games  Journalism     Music  Photography  \
# 0          -0.450383 -0.263136 -0.316468   -0.111451 -0.396160     5.726004
# 1          -0.450383 -0.263136 -0.316468   -0.111451 -0.396160    -0.174642
# 2          -0.450383 -0.263136 -0.316468   -0.111451 -0.396160     5.726004
# 3          -0.450383 -0.263136 -0.316468   -0.111451  2.524234    -0.174642
# 4           2.220334 -0.263136 -0.316468   -0.111451 -0.396160    -0.174642
# ...              ...       ...       ...         ...       ...          ...
# 100760     -0.450383 -0.263136 -0.316468   -0.111451 -0.396160    -0.174642
# 100761      2.220334 -0.263136 -0.316468   -0.111451 -0.396160    -0.174642
# 100762     -0.450383 -0.263136 -0.316468   -0.111451  2.524234    -0.174642
# 100763     -0.450383 -0.263136 -0.316468   -0.111451 -0.396160    -0.174642
# 100764     -0.450383 -0.263136 -0.316468   -0.111451 -0.396160    -0.174642
#
#         Publishing  Technology   Theater
# 0        -0.336600   -0.295945 -0.183823
# 1        -0.336600   -0.295945 -0.183823
# 2        -0.336600   -0.295945 -0.183823
# 3        -0.336600   -0.295945 -0.183823
# 4        -0.336600   -0.295945 -0.183823
# ...            ...         ...       ...
# 100760   -0.336600   -0.295945 -0.183823
# 100761   -0.336600   -0.295945 -0.183823
# 100762   -0.336600   -0.295945 -0.183823
# 100763   -0.336600   -0.295945 -0.183823
# 100764    2.970888   -0.295945 -0.183823
#
# [100765 rows x 22 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig, ax = plt.subplots(num=None, figsize=(14,6), dpi=80, facecolor='w', edgecolor='k')
ax = fig.gca(projection='3d')
ax.scatter(X_train['goal'],X_train['pledged'],X_train['backers'],c=y_train)
# Out:
# C:\Users\Moata\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Requested projection is different from current axis projection, creating new axis with requested projection.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from mpl_toolkits.mplot3d import Axes3D
fig, ax = plt.subplots(num=None, figsize=(14,6), dpi=80, facecolor='w', edgecolor='k')
ax = fig.gca(projection='3d')
ax.scatter(X_train['goal'],X_train['pledged'],X_train['timeframe'],c=y_train)
# Out:
# C:\Users\Moata\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Requested projection is different from current axis projection, creating new axis with requested projection.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from mpl_toolkits.mplot3d import Axes3D
fig, ax = plt.subplots(num=None, figsize=(14,6), dpi=80, facecolor='w', edgecolor='k')
ax = fig.gca(projection='3d')
ax.scatter(X_train['goal'],X_train['backers'],X_train['timeframe'],c=y_train)
# Out:
# C:\Users\Moata\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Requested projection is different from current axis projection, creating new axis with requested projection.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from mpl_toolkits.mplot3d import Axes3D
fig, ax = plt.subplots(num=None, figsize=(14,6), dpi=80, facecolor='w', edgecolor='k')
ax = fig.gca(projection='3d')
ax.scatter(X_train['pledged'],X_train['backers'],X_train['timeframe'],c=y_train)
# Out:
# C:\Users\Moata\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Requested projection is different from current axis projection, creating new axis with requested projection.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# From above scatters we can see that we can train data as we see mostly separation between failed an succeeded proejcts

# %% [markdown]
# # Training with Logistics regression

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train,y_train)
trainscore=clf.score(X_train,y_train)
testscore=clf.score(X_test,y_test)
print('training score: ',trainscore,'  , test score: ',testscore)
# Out:
# C:\Users\Moata\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# training score:  0.9122939080364256   , test score:  0.9116856051208256
